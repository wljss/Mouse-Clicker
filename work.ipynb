# %%
import sys
from PyQt5.QtWidgets import QMainWindow,QApplication

class AutoClickerGUI(QMainWindow):
    def __init__(self):
        super().__init__()
        self.initUI()
    
    def initUI(self):
        self.setWindowTitle('自动连点器')

if __name__ == '__main__' :
    app = QApplication(sys.argv)
    window = AutoClickerGUI()
    window.show()
    sys.exit(app.exec_()) #启动事件循环
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\24508\Anaconda3\envs\pyqt\lib\site-packages\IPython\core\interactiveshell.py:3560: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
